# %% [markdown]
# # Example: Fun with Iteration Patterns for Arrays, Sets, and Dictionaries
# Iteration is the repeated execution of a block of code, typically used to process elements in a collection or to perform repeated actions until a condition is met.
# > __Iteration__ is an _extremely common_ fundamental concept used in nearly all applications. It appears in tasks ranging from simple loops over arrays to complex algorithms in data processing, simulation, and machine learning, making it an essential tool in nearly every programming language and domain.
#
# In this example, we'll explore the two iteration patterns that you'll likely encounter in your everyday life:
# * __For loops__: A for loop is a control structure that repeatedly executes a code block for each element in a specified sequence or range. It is commonly used to iterate over collections like arrays or lists, or to perform a fixed number of repetitions.
# * __While loops__: A while loop is a control structure that repeatedly executes a code block if a specified condition remains true. It is typically used when the number of iterations is not known in advance and depends on dynamic conditions during execution.
#
# I'm ready to get going, so let's go!
# ___

# %% [markdown]
# ## Setup, Data, and Prerequisites
# We set up the computational environment by including the `Include.jl` file and loading any needed resources.
#
# > __Include__: The [include command](https://docs.julialang.org/en/v1/base/base/#include) evaluates the contents of the input source file, `Include.jl`, in the notebook's global scope. The `Include.jl` file sets paths, loads required external packages, etc.
#
# Let's set up the computational environment.

# %%
include(joinpath(@__DIR__, "Include.jl"));

# %% [markdown]
# For additional information on Julia functions and types used in this material, see the [Julia programming language documentation](https://docs.julialang.org/en/v1/). In addition, we'll also use [the `VLDataScienceMachineLearningPackage.jl` package](https://github.com/varnerlab/VLDataScienceMachineLearningPackage.jl). Check out [the documentation](https://varnerlab.github.io/VLDataScienceMachineLearningPackage.jl/dev/) for more information on its functions, types, and data.
# ___

# %% [markdown]
# ## Example 1: Basic for-loop iteration patterns for Ordered Collections
# Let's start by looking at the basic structure of [a for-loop.](https://docs.julialang.org/en/v1/base/base/#for) A [for-loop](https://docs.julialang.org/en/v1/base/base/#for) has a header and a body.
# > __Loop header:__ The __header__ in a for-loop specifies how many times the loop will iterate. The loop `index` is passed into the loop's _body_, where you put your logic. The `index` is always a new variable, even if a variable of the same name exists in the enclosing scope.
#
# In Julia, the [for-loop](https://docs.julialang.org/en/v1/base/base/#for) has its _local scope_ that captures variables from the outside but doesn't pass new variables created inside the loop to the outside unless they already exist. The [local scope of the for loop](https://docs.julialang.org/en/v1/manual/variables-and-scoping/#local-scope) ends with the `end` keyword.
#
# > __Scope:__ In programming, __scope__ refers to the region of code where a variable or identifier is defined and accessible. It determines the visibility and lifetime of variables, helping to manage the namespace and prevent naming conflicts.
#
# Let's do a simple example where we create an `Array{Float64,1}` holding random values, iterate over this array using a for loop, and print using the [println function](https://docs.julialang.org/en/v1/base/io-network/#Base.println) each random value.

# %%
let
    
    number_of_elements = 5; # how many items do we want?
    random_vector_array = rand(number_of_elements); # create an array of random 64-bit floating-point values
    value = nothing # declare a variable outside the loop.
    
    for i ∈ 1:number_of_elements
        value = random_vector_array[i];
        println("The index i = $(i) and the value = $(random_vector_array[i])");
    end # end of for loop scope
    value # what gets printed?
end
# Out:
# The index i = 1 and the value = 0.010084412413528643
# The index i = 2 and the value = 0.6048977590711205
# The index i = 3 and the value = 0.7231660942627742
# The index i = 4 and the value = 0.5495127052418961
# The index i = 5 and the value = 0.1595028804566252
# 0.1595028804566252

# %% [markdown]
# ### Eachindex
# Another [for-loop](https://docs.julialang.org/en/v1/base/base/#for) pattern is the [eachindex pattern](https://docs.julialang.org/en/v1/base/arrays/#Base.eachindex). We use the [eachindex pattern](https://docs.julialang.org/en/v1/base/arrays/#Base.eachindex) when we don't explicitly know how many elements we have in an ordered collection, but we want all of the elements in order.

# %%
let
    number_of_elements = 5; # how many items do we want?
    random_vector_array = rand(number_of_elements); # create an array of random 64-bit floating-point values
    N = length(random_vector_array)
    for i ∈ eachindex(random_vector_array)        
        value = random_vector_array[i];
        println("The index i = $(i) and the value = $(value)"); # body
    end
end
# Out:
# The index i = 1 and the value = 0.763784187702727
# The index i = 2 and the value = 0.6679822040972494
# The index i = 3 and the value = 0.048038122823504725
# The index i = 4 and the value = 0.7956762125226814
# The index i = 5 and the value = 0.9445454220445945

# %% [markdown]
# ### Direct iteration
# Suppose we don't care about the index $i$, but instead want only the values; we can iterate over the elements of a collection directly. For example, the code block below accesses the values of the `random_vector_array`  directly, but __NOT__ their indexes:

# %%
let
    number_of_elements = 5; # how many items do we want?
    random_vector_array = rand(number_of_elements); # create an array of random 64-bit floating-point values
    
    for value ∈ random_vector_array # for value in collection
        println("Only the value = $(value)"); # body
    end
end
# Out:
# Only the value = 0.10784101706096672
# Only the value = 0.8889998073021319
# Only the value = 0.7839560214273642
# Only the value = 0.23579172533928483
# Only the value = 0.33473588733528825

# %% [markdown]
# ### Iterate over other things besides an array?
# Sure! We can iterate over other ordered (and unordered) collections, not just arrays! For example, we can iterate over [tuples](https://docs.julialang.org/en/v1/manual/functions/#Tuples), fixed-length _immutable_ ordered containers that can hold any values.
#
# Let's build a tuple holding some `Int64` types and iterate over these using the [eachindex pattern](https://docs.julialang.org/en/v1/base/arrays/#Base.eachindex).
#
# The previous examples used the [println function](https://docs.julialang.org/en/v1/base/io-network/#Base.println) to print output [to `stdout`](https://docs.julialang.org/en/v1/base/io-network/#Base.stdout); here, we show another approach that does the same thing, namely using the [@show macro](https://docs.julialang.org/en/v1/base/base/#Base.@show) which prints one or more expressions, and their results, [to `stdout`](https://docs.julialang.org/en/v1/base/io-network/#Base.stdout):

# %%
example_tuple= let
    example_tuple = (1,2,3,6,5,4,1,1,1,1, 'c', "test")
    
    for i ∈ eachindex(example_tuple) # header: for index in index collection
        @show (i, example_tuple[i]) # body
    end

    example_tuple
end
# Out:
# (i, example_tuple[i]) = (1, 1)
# (i, example_tuple[i]) = (2, 2)
# (i, example_tuple[i]) = (3, 3)
# (i, example_tuple[i]) = (4, 6)
# (i, example_tuple[i]) = (5, 5)
# (i, example_tuple[i]) = (6, 4)
# (i, example_tuple[i]) = (7, 1)
# (i, example_tuple[i]) = (8, 1)
# (i, example_tuple[i]) = (9, 1)
# (i, example_tuple[i]) = (10, 1)
# (i, example_tuple[i]) = (11, 'c')
# (i, example_tuple[i]) = (12, "test")
# (1, 2, 3, 6, 5, 4, 1, 1, 1, 1, 'c', "test")

# %%
example_tuple[13] = "What???"
# Out:
# MethodError: no method matching setindex!(::Tuple{Int64, Int64, Int64, Int64, Int64, Int64, Int64, Int64, Int64, Int64, Char, String}, ::String, ::Int64)
# The function `setindex!` exists, but no method is defined for this combination of argument types.
#
# Stacktrace:
#  [1] top-level scope
#    @ In[13]:1

# %% [markdown]
# ___

# %% [markdown]
# Let's build a `Set{Char}` of values, and then directly iterate the set (where we show the value at each iteration using [the `@show` macro](https://docs.julialang.org/en/v1/base/base/#Base.@show)

# %%
# let
#     example_set = Set{Char}(['A','B','C','D','R','U','S','T','A', 'G']);
#     for i ∈ eachindex(example_set)
#         @show example_set[i]
#     end
# end

# %% [markdown]
# ### Dictionary
# [A Dictionary is an associative container](https://docs.julialang.org/en/v1/base/collections/#Base.Dict) that stores key–value pairs, allowing lookup, insertion, and deletion of values based on their unique keys. While significantly different than an array, we can still traverse a dictionary [using a for-loop](https://docs.julialang.org/en/v1/base/base/#for).
#
# We gathered a daily open-high-low-close `dataset` for each firm in the [S&P500](https://en.wikipedia.org/wiki/S%26P_500) from `01-03-2014` until `12-31-2024`, along with data for a few exchange-traded funds and volatility products during that time.
#
# Let's load the `orignal_dataset` by calling the `MyMarketDataSet()` function and remove firms that do not have the maximum number of trading days. The cleaned dataset $\mathcal{D}$ will be stored in the `dataset` variable.
#
# When we use a [for-loop](https://docs.julialang.org/en/v1/base/base/#for) with a [Dictionary](https://docs.julialang.org/en/v1/base/collections/#Dictionaries), which is an unordered collection of `key=>value` pairs, we get both the `key` and `value` as the iteration variable organized as a `tuple.`

# %%
original_dataset = MyMarketDataSet() |> x-> x["dataset"];
# Out:
# UndefVarError: `MyMarketDataSet` not defined in `Main`
# Suggestion: check for spelling errors or missing imports.
#
# Stacktrace:
#  [1] top-level scope
#    @ In[18]:1

# %%
original_dataset
# Out:
# UndefVarError: `original_dataset` not defined in `Main`
# Suggestion: check for spelling errors or missing imports.

# %%
original_dataset["AAPL"] # Hmmm. we access the elements of dictionary like an array?
# Out:
# UndefVarError: `original_dataset` not defined in `Main`
# Suggestion: check for spelling errors or missing imports.
#
# Stacktrace:
#  [1] top-level scope
#    @ In[20]:1

# %% [markdown]
# #### Clean the data
# Not all tickers in our dataset have the maximum number of trading days for various reasons, e.g., acquisition or de-listing events. Let's collect only those tickers with the maximum number of trading days.
#
# First, let's compute the number of records for a firm that we know has a maximum value, e.g., `AAPL`, and save that value in the `maximum_number_trading_days::Int64` variable:

# %%
maximum_number_trading_days = original_dataset["AAPL"] |> nrow; # nrow? (check out: DataFrames.jl)
# Out:
# UndefVarError: `original_dataset` not defined in `Main`
# Suggestion: check for spelling errors or missing imports.
#
# Stacktrace:
#  [1] top-level scope
#    @ In[22]:1

# %% [markdown]
# Now, let's iterate through our data and collect only tickers with `maximum_number_trading_days` records. Save that data in the `dataset::Dict{String,DataFrame}` variable:

# %%
dataset = let

    # initialize -
    dataset = Dict{String, DataFrame}();

    # iterate through the dictionary; we can't guarantee a particular order
    for (ticker, data) ∈ original_dataset  # we get each (K, V) pair!
        if (nrow(data) == maximum_number_trading_days) # what is this doing?
            dataset[ticker] = data;
        else
            println("Ticker $(ticker) is not full data")
        end
    end
    dataset; # return
end;
# Out:
# UndefVarError: `original_dataset` not defined in `Main`
# Suggestion: check for spelling errors or missing imports.
#
# Stacktrace:
#  [1] top-level scope
#    @ ./In[24]:7

# %% [markdown]
# How many firms do we have the full number of trading days? Let's use [the `length(...)` method](https://docs.julialang.org/en/v1/base/collections/#Base.length) - notice this works for dictionaries, in addition to arrays and sets!

# %%
length(dataset) # tells us how many keys are in the dictionary
# Out:
# UndefVarError: `dataset` not defined in `Main`
# Suggestion: check for spelling errors or missing imports.
#
# Stacktrace:
#  [1] top-level scope
#    @ In[26]:1

# %% [markdown]
# Let's load the `original_dataset` by calling the `MyMarketDataSet()` function and remove firms that do not have the maximum number of trading days. The cleaned dataset $\mathcal{D}$ will be stored in the `dataset` variable.

# %% [markdown]
# ## Example 3: While loop iteration Pattern
# A for loop is used when the number of iterations is known. In contrast, a while loop is used when iterations depend on a condition evaluated before each loop, making it better for dynamic repetition. A while loop also has a header and a body, but they differ from a for loop:
# > __While loop__: In a while loop, the header contains the loop condition evaluated before each iteration to determine whether the loop should continue. The body is the block of code that executes repeatedly as long as the condition in the header remains true.
#
# Let's do a common while loop pattern, where we iterate all the items in a collection until we reach the end of the collection. In this case, we will use a `Set{String}` and iterate over it using a while loop.
#
# Let's start by building a set of possible student firstnames using [the `MyCommonForenameDataset()`](https://varnerlab.github.io/VLDataScienceMachineLearningPackage.jl/dev/data/#VLDataScienceMachineLearningPackage.MyCommonForenameDataset) function from [the `VLDataScienceMachineLearningPackage.jl` package.](https://github.com/varnerlab/VLDataScienceMachineLearningPackage.jl). We'll store the forenames in `set_of_firstnames::Set{String}` variable.

# %%
set_of_firstnames = let 
    
    # initialize -
    set_of_firstnames = Set{String}();
    fornames_df = MyCommonForenameDataset(); # firstnames dataset from the VLDataScienceMachineLearningPackage.jl package

    # build fornames set - 
    for name in eachrow(fornames_df)
        push!(set_of_firstnames, name["Romanized Name"]);
    end

    set_of_firstnames # return -
end;

# %%
set_of_firstnames
# Out:
# Set{String} with 1394 elements:
#   "Gustavs"
#   "Anohito"
#   "Marks"
#   "Djamel"
#   "Aleks"
#   "Aleksandre"
#   "David"
#   "Ayşa"
#   "Ya-ting"
#   "Amina"
#   "Helma"
#   "Emmanuel"
#   "Yassin"
#   "Alina"
#   "Tobias"
#   "Antonio"
#   "Ao"
#   "Baran"
#   "Muhamad"
#   "Zoé"
#   "Yara"
#   "Siphosethu"
#   "Yuna"
#   "Viktoriya"
#   "Karine"
#   ⋮

# %% [markdown]
# Next, let's iterate over the `set_of_firstnames` using a while loop. We'll use the [pop!](https://docs.julialang.org/en/v1/base/collections/#Base.pop!) function to remove and return an arbitrary element from the set. We'll continue to iterate until the set is empty, or we hit the maximum number of iterations, which we set to `10` in this example.

# %%
let

    # initialize -
    should_stop_while_loop = false;
    max_names_to_pop = 25000; # how many names do we want to pop?
    localset = copy(set_of_firstnames); # make a copy of the set

    while should_stop_while_loop == false
        first_name_value = pop!(localset); # remove and return an element from the set

        println("Popped element = $(first_name_value)");

        # check iteration condition -
        if (isempty(localset) == true) || (max_names_to_pop == 1) # what is an if statement?
            should_stop_while_loop = true;
        else
            max_names_to_pop -= 1; # decrement the counter
        end
    end
end
# Out:
# Popped element = Gustavs
# Popped element = Anohito
# Popped element = Marks
# Popped element = Djamel
# Popped element = Aleks
# Popped element = Aleksandre
# Popped element = David
# Popped element = Ayşa
# Popped element = Ya-ting
# Popped element = Amina
# Popped element = Helma
# Popped element = Emmanuel
# Popped element = Yassin
# Popped element = Alina
# Popped element = Tobias
# Popped element = Antonio
# Popped element = Ao
# Popped element = Baran
# Popped element = Muhamad
# Popped element = Zoé
# Popped element = Yara
# Popped element = Siphosethu
# Popped element = Yuna
# Popped element = Viktoriya
# Popped element = Karine
# Popped element = Vesna
# Popped element = Alanoud
# Popped element = Dalila
# Popped element = Cillian
# Popped element = Lamija
# Popped element = Malen
# Popped element = Niharika
# Popped element = Bautista
# Popped element = Yeva
# Popped element = Rin
# Popped element = Gabriel
# Popped element = Miguel Ángel
# Popped element = Roberts
# Popped element = Diego
# Popped element = Robert
# Popped element = Mustafa
# Popped element = Sofía
# Popped element = Väinö
# Popped element = Kai
# Popped element = Viktoría
# Popped element = Emelia
# Popped element = Angel
# Popped element = Ion
# Popped element = Alexandra
# Popped element = Celeste
# Popped element = Ayla
# Popped element = Khawla
# Popped element = Matteo
# Popped element = Hugo
# Popped element = Aoife
# Popped element = Doha
# Popped element = José
# Popped element = Nicolás
# Popped element = Paul
# Popped element = Ljiljana
# Popped element = Amēlija
# Popped element = Vladyslav
# Popped element = Yìzé
# Popped element = Abd
# Popped element = Andria
# Popped element = Josiah
# Popped element = Ferndo
# Popped element = Asja
# Popped element = Sesili
# Popped element = Aikaterini
# Popped element = Nurislam
# Popped element = Alinur
# Popped element = Vasiliki
# Popped element = Soo-ah
# Popped element = Keven
# Popped element = Hana
# Popped element = Nóa
# Popped element = Jana
# Popped element = Ivy
# Popped element = Sergei
# Popped element = Seo-yun
# Popped element = Embla
# Popped element = Barbara
# Popped element = Viktoria
# Popped element = Seo-ah
# Popped element = Sama
# Popped element = Juan
# Popped element = Asiya
# Popped element = Harper
# Popped element = Yǔtóng
# Popped element = Milica
# Popped element = Tatiana
# Popped element = Isabelle
# Popped element = Adama
# Popped element = Sólja
# Popped element = Iker
# Popped element = Rachid
# Popped element = Saar
# Popped element = Mykhaylo
# Popped element = Tereza
# Popped element = Leevi
# Popped element = Lan
# Popped element = Ji-yoo
# Popped element = Shu-chen
# Popped element = Taim
# Popped element = Sophia
# Popped element = Mikael
# Popped element = Karima
# Popped element = Ralfs
# Popped element = Lucas
# Popped element = Nicole
# Popped element = Eleni
# Popped element = Oisha
# Popped element = Edward
# Popped element = Maximilian
# Popped element = Emily
# Popped element = Georgios
# Popped element = Aya
# Popped element = Sumayah
# Popped element = Göktug
# Popped element = Melisa
# Popped element = Hjørdis
# Popped element = Timofey
# Popped element = Melissa
# Popped element = Katla
# Popped element = Maksym
# Popped element = Adam
# Popped element = Dušan
# Popped element = Jokūbas
# Popped element = Afonso
# Popped element = Konul
# Popped element = Jovan
# Popped element = Abdulrahman
# Popped element = Aisha
# Popped element = Gogo
# Popped element = Jori
# Popped element = Helena
# Popped element = Beatrice
# Popped element = Dārta
# Popped element = Jökull
# Popped element = Juan Andrés
# Popped element = Lydia
# Popped element = Sakeena
# Popped element = Gita
# Popped element = Mùyáng
# Popped element = Milena
# Popped element = Merjem
# Popped element = Ivalu
# Popped element = Gabriele
# Popped element = Ricardo
# Popped element = Koa
# Popped element = Amahle
# Popped element = Rory
# Popped element = Manua
# Popped element = Sevda
# Popped element = Boglárka
# Popped element = Sheikh
# Popped element = Roxana
# Popped element = Beatriz
# Popped element = Stevenson
# Popped element = Adele
# Popped element = Viktor
# Popped element = Markel
# Popped element = Fahad
# Popped element = Yamato
# Popped element = Hydar
# Popped element = Aylin
# Popped element = Susan
# Popped element = Aimar
# Popped element = AbulFazl
# Popped element = Oumou
# Popped element = Safiya
# Popped element = Leonor
# Popped element = Aline
# Popped element = Antonella
# Popped element = Jessica
# Popped element = Ramón
# Popped element = Ren
# Popped element = Georgi
# Popped element = Frida
# Popped element = Matthildur
# Popped element = Olga
# Popped element = Mia
# Popped element = Hasan
# Popped element = Antônio
# Popped element = Amelja
# Popped element = Karam
# Popped element = Raphael
# Popped element = Tarana
# Popped element = Lio
# Popped element = Alysha
# Popped element = Juliana
# Popped element = Rethabile
# Popped element = Lwandle
# Popped element = Esma
# Popped element = Snežana
# Popped element = Ye-jun
# Popped element = Levente
# Popped element = Joel
# Popped element = Vár
# Popped element = An
# Popped element = Catalina
# Popped element = Roghayyeh
# Popped element = Zainab
# Popped element = Inès
# Popped element = Kevin
# Popped element = Rania
# Popped element = Benedita
# Popped element = Solomiya
# Popped element = Lili
# Popped element = Paraskevi
# Popped element = Ramazan
# Popped element = Maria Alice
# Popped element = Lea
# Popped element = Benicio
# Popped element = Sebastian
# Popped element = Damjan
# Popped element = Iben
# Popped element = Miraç
# Popped element = Josefa
# Popped element = Aksel
# Popped element = Malachi
# Popped element = Karen
# Popped element = Althea
# Popped element = Shaikha
# Popped element = Hussa
# Popped element = Léa
# Popped element = Islande
# Popped element = Ezekiel
# Popped element = Norsaq
# Popped element = Hàoyǔ
# Popped element = Lethokuhle
# Popped element = Farah
# Popped element = Annie
# Popped element = Lovelie
# Popped element = Dhia
# Popped element = Uri
# Popped element = Hassan
# Popped element = Carlos
# Popped element = Abdel-Rahman
# Popped element = Lilit
# Popped element = Daniel
# Popped element = Zahra
# Popped element = Paula
# Popped element = Suha
# Popped element = Kiaan
# Popped element = Jelena
# Popped element = Vojtěch
# Popped element = Areni
# Popped element = Trinidad
# Popped element = Lidia
# Popped element = thaniel
# Popped element = Amal
# Popped element = Ulloriaq
# Popped element = Matěj
# Popped element = Nahia
# Popped element = Jan
# Popped element = Shams
# Popped element = Matvey
# Popped element = Juliette
# Popped element = Arpi
# Popped element = Naura
# Popped element = Pierre
# Popped element = Lilja
# Popped element = Selim
# Popped element = Boris
# Popped element = Arman
# Popped element = Jakub
# Popped element = Ajda
# Popped element = Tadhg
# Popped element = Maryja
# Popped element = Willow
# Popped element = Nehir
# Popped element = Agnes
# Popped element = Oyunbileg
# Popped element = Roko
# Popped element = Hessa
# Popped element = João
# Popped element = Nathan
# Popped element = Ximena
# Popped element = Ashot
# Popped element = Avigail
# Popped element = Gamila
# Popped element = Noel
# Popped element = Alexander
# Popped element = Nare
# Popped element = Peter
# Popped element = Fátima
# Popped element = Nuray
# Popped element = Irati
# Popped element = Hoda
# Popped element = Somporn
# Popped element = Christos
# Popped element = Amelija
# Popped element = Chun-hung
# Popped element = Leyla
# Popped element = Mohammad
# Popped element = Tarita
# Popped element = Evelyn
# Popped element = Nuka
# Popped element = Jón
# Popped element = Margaret
# Popped element = Alma
# Popped element = Nouf
# Popped element = Daniel Alejandro
# Popped element = Panagiotis
# Popped element = Seo-jun
# Popped element = Natálie
# Popped element = Ivik
# Popped element = Mees
# Popped element = Matas
# Popped element = Modibo
# Popped element = Adrians
# Popped element = Banele
# Popped element = Minato
# Popped element = Olivér
# Popped element = Pedro
# Popped element = Luknė
# Popped element = Maša
# Popped element = Aras
# Popped element = Asmita
# Popped element = Juana
# Popped element = Daisy
# Popped element = Dunja
# Popped element = Emma
# Popped element = Ioannis
# Popped element = Darija
# Popped element = Nagi
# Popped element = Defne
# Popped element = Lisakhanya
# Popped element = Júlia
# Popped element = Raphaël
# Popped element = Zoran
# Popped element = Li-hua
# Popped element = Maitê
# Popped element = Jon
# Popped element = Mikayel
# Popped element = Ángel
# Popped element = Felix
# Popped element = Hamza
# Popped element = Ecrin
# Popped element = Vaea
# Popped element = Mark
# Popped element = Rose-Merline
# Popped element = Aino
# Popped element = Matei
# Popped element = Mina
# Popped element = Luis
# Popped element = Joshua
# Popped element = Hanna
# Popped element = Alicja
# Popped element = Malu
# Popped element = Valeria
# Popped element = Manaia
# Popped element = Evie
# Popped element = Mira
# Popped element = Eman
# Popped element = Sukhbaаtar
# Popped element = Ayim
# Popped element = Jules
# Popped element = Assia
# Popped element = Do-yun
# Popped element = Jude
# Popped element = Tiare
# Popped element = Théo
# Popped element = Ji-woo
# Popped element = Giorgi
# Popped element = Marc
# Popped element = Androula
# Popped element = Andreea
# Popped element = Farida
# Popped element = Oleksandra
# Popped element = Niko
# Popped element = Lív
# Popped element = Reema
# Popped element = Margarida
# Popped element = Sakura
# Popped element = Karolína
# Popped element = Aïcha
# Popped element = Izz
# Popped element = Dragana
# Popped element = Luna
# Popped element = Máté
# Popped element = Javier
# Popped element = Nathaniel
# Popped element = Luka
# Popped element = Mahdi
# Popped element = Toivo
# Popped element = Ivaana
# Popped element = Biel
# Popped element = Gabor
# Popped element = Aria
# Popped element = Manuel
# Popped element = William
# Popped element = Asya
# Popped element = Florence
# Popped element = Artyom
# Popped element = Jorge
# Popped element = Ilija
# Popped element = Moussa
# Popped element = Milan
# Popped element = Pipaluk
# Popped element = Ari
# Popped element = Amir
# Popped element = Oumar
# Popped element = Aiden
# Popped element = Esperanza
# Popped element = Mahesh
# Popped element = Nora
# Popped element = Artem
# Popped element = Yuina
# Popped element = Ju-won
# Popped element = Maysoun
# Popped element = Lena
# Popped element = Michael
# Popped element = Keanu
# Popped element = Tróndur
# Popped element = Bruno
# Popped element = Tigran
# Popped element = I-chun
# Popped element = Amaris
# Popped element = Sofia
# Popped element = Inaya
# Popped element = Isabel
# Popped element = Julen
# Popped element = Teiki
# Popped element = Gamalat
# Popped element = Wilson
# Popped element = Armine
# Popped element = Sōma
# Popped element = Nikodem
# Popped element = Raul
# Popped element = Fatemeh
# Popped element = Meryem
# Popped element = Anastasiya
# Popped element = Zahid
# Popped element = Mersana
# Popped element = Min-jun
# Popped element = Aurora
# Popped element = Jack
# Popped element = Aada
# Popped element = Wateen
# Popped element = Aleksandar
# Popped element = Usman
# Popped element = Davud
# Popped element = Shaimaa
# Popped element = Maria
# Popped element = Azariah
# Popped element = Siddhartha
# Popped element = Millie
# Popped element = Ali-Reza
# Popped element = Farzana
# Popped element = Vasilije
# Popped element = Marija
# Popped element = Charbel
# Popped element = Gabija
# Popped element = Nutsa
# Popped element = Riccardo
# Popped element = Michal
# Popped element = Dominik
# Popped element = Fatin
# Popped element = Oskar
# Popped element = Mila
# Popped element = Eevi
# Popped element = Antoni
# Popped element = Zümra
# Popped element = Cecília
# Popped element = Džan
# Popped element = Kaia
# Popped element = Ana
# Popped element = Tatsuki
# Popped element = Widelene
# Popped element = Julia
# Popped element = Sakineh
# Popped element = Maximiliano
# Popped element = Aadhya
# Popped element = Carolina
# Popped element = José Luis
# Popped element = Titaua
# Popped element = Iman
# Popped element = Inutsiaq
# Popped element = Marios
# Popped element = Jakov
# Popped element = Charlie
# Popped element = Rowan
# Popped element = Luana
# Popped element = Yu-jun
# Popped element = Dylan
# Popped element = Indira
# Popped element = Ane
# Popped element = Fiadh
# Popped element = Nika
# Popped element = Chih-chiang
# Popped element = Amar
# Popped element = Ambra
# Popped element = Maligiaq
# Popped element = Ayra
# Popped element = Yelena
# Popped element = Manuela
# Popped element = Aziz
# Popped element = Nur
# Popped element = Inuk
# Popped element = Fūma
# Popped element = Stanisław
# Popped element = Lourenço
# Popped element = Léna
# Popped element = Si-woo
# Popped element = Angeline
# Popped element = Ella
# Popped element = Jade
# Popped element = Haruto
# Popped element = Fatemeh-Zahra
# Popped element = Nikolaos
# Popped element = Eva
# Popped element = Mehdi
# Popped element = Beshoi
# Popped element = Hovhannes
# Popped element = Nikau
# Popped element = Irene
# Popped element = Miki
# Popped element = Alberte
# Popped element = Sultan
# Popped element = Martin
# Popped element = Sóley
# Popped element = Sofija
# Popped element = Khongordzol
# Popped element = Konstantinos
# Popped element = Michail
# Popped element = Saliha
# Popped element = Stefan
# Popped element = Puteri
# Popped element = Heikapu
# Popped element = Angeliki
# Popped element = Viktória
# Popped element = Alparslan
# Popped element = Karim
# Popped element = Fatma
# Popped element = Azra
# Popped element = Adéla
# Popped element = Noor
# Popped element = Siti
# Popped element = Óliver
# Popped element = Isak
# Popped element = Joseph
# Popped element = Dimitar
# Popped element = Armen
# Popped element = Saga
# Popped element = Stanley
# Popped element = Azaria
# Popped element = Hàorán
# Popped element = Camille
# Popped element = Hussain
# Popped element = Chien-hung
# Popped element = Victoria
# Popped element = Aoi
# Popped element = Amara
# Popped element = Mahamadou
# Popped element = Turki
# Popped element = Tunar
# Popped element = Emīls
# Popped element = Harry
# Popped element = Sita
# Popped element = Alise
# Popped element = Arthur
# Popped element = Arianna
# Popped element = Julija
# Popped element = Chih-ming
# Popped element = Mùchén
# Popped element = Aldiyar
# Popped element = Lev
# Popped element = Adomas
# Popped element = Vuk
# Popped element = Faisal
# Popped element = Francesco
# Popped element = Andrias
# Popped element = Lile
# Popped element = Maddi
# Popped element = Emilija
# Popped element = Haru
# Popped element = Freya
# Popped element = Paninnguaq
# Popped element = Francisca
# Popped element = Julieta
# Popped element = Nikola
# Popped element = Louise
# Popped element = Fadi
# Popped element = Tareq
# Popped element = Jovana
# Popped element = Anahit
# Popped element = Souleymane
# Popped element = Irina
# Popped element = Mari
# Popped element = Lin
# Popped element = Dhruv
# Popped element = Samyar
# Popped element = Matija
# Popped element = Imene
# Popped element = Tiago
# Popped element = Layla
# Popped element = Pol
# Popped element = Rei
# Popped element = Herkus
# Popped element = Guðrún
# Popped element = Youssef
# Popped element = Éabha
# Popped element = Mariana
# Popped element = Sunita
# Popped element = June
# Popped element = Logan
# Popped element = Harun
# Popped element = Marco Antonio
# Popped element = George
# Popped element = Andreas
# Popped element = Yìhán
# Popped element = Osman
# Popped element = Lejla
# Popped element = Santiago
# Popped element = Shu-chuan
# Popped element = Christina
# Popped element = Moeata
# Popped element = Iminathi
# Popped element = Taha
# Popped element = Asta
# Popped element = Markus
# Popped element = Ali Asaf
# Popped element = Linda
# Popped element = Rasmus
# Popped element = Rafael
# Popped element = Radmila
# Popped element = Agustina
# Popped element = Lenna
# Popped element = Kamilė
# Popped element = Nino
# Popped element = Vedant
# Popped element = Vamika
# Popped element = Noam
# Popped element = Leon
# Popped element = Hannah
# Popped element = Khadije
# Popped element = Shahem
# Popped element = Ben
# Popped element = Regina
# Popped element = Harris
# Popped element = Isabella
# Popped element = Fran
# Popped element = Samvel
# Popped element = Atlas
# Popped element = Daniels
# Popped element = Mateo
# Popped element = Bilal
# Popped element = Maneh
# Popped element = Ayesha
# Popped element = Alexey
# Popped element = Natalija
# Popped element = Ámbar
# Popped element = Jonas
# Popped element = Aarya
# Popped element = Valentina
# Popped element = Naïm
# Popped element = Naranbaatar
# Popped element = Tamar
# Popped element = María
# Popped element = Jouri
# Popped element = Violeta
# Popped element = Matyáš
# Popped element = Kora
# Popped element = Zeynep
# Popped element = Hashem
# Popped element = Melokuhle
# Popped element = Dejan
# Popped element = Noah
# Popped element = Fajr
# Popped element = Reina
# Popped element = Francisco
# Popped element = Marti
# Popped element = Fanta
# Popped element = Delfina
# Popped element = Oihan
# Popped element = Luiz
# Popped element = Yekaterina
# Popped element = Olivia
# Popped element = Mahammad
# Popped element = Livia
# Popped element = Şerife
# Popped element = Camila
# Popped element = Saqib
# Popped element = Chia-hao
# Popped element = Ömer
# Popped element = Bakary
# Popped element = Dyllan
# Popped element = Yua
# Popped element = James
# Popped element = Binita
# Popped element = Zalán
# Popped element = Susanna
# Popped element = Lur
# Popped element = Mario
# Popped element = Omer
# Popped element = Sara
# Popped element = Andrei
# Popped element = Teodora
# Popped element = Elene
# Popped element = Gilli
# Popped element = Gunay
# Popped element = Habib
# Popped element = Maya
# Popped element = Mattia
# Popped element = Yūna
# Popped element = Moana
# Popped element = Rabina
# Popped element = Ajla
# Popped element = Bence
# Popped element = Michalis
# Popped element = Chin-lung
# Popped element = Mariam
# Popped element = Theo
# Popped element = Valdemar
# Popped element = Nesreen
# Popped element = Hur
# Popped element = Nikol
# Popped element = Anastasija
# Popped element = Jakob
# Popped element = Laia
# Popped element = Rose
# Popped element = Bandar
# Popped element = Bishal
# Popped element = Marwa
# Popped element = Sienna
# Popped element = Georgia
# Popped element = Lina
# Popped element = Kyriaki
# Popped element = Demetre
# Popped element = Gabriela
# Popped element = Vusal
# Popped element = Lėja
# Popped element = Elli
# Popped element = Zahir
# Popped element = Marya
# Popped element = Hinano
# Popped element = Lia
# Popped element = Nilay
# Popped element = Lana
# Popped element = Imogen
# Popped element = Amir-Hossein
# Popped element = Yasmin
# Popped element = Juan Carlos
# Popped element = Gayane
# Popped element = Marcos
# Popped element = Mikołaj
# Popped element = Syed
# Popped element = Ludovica
# Popped element = Anna
# Popped element = Gunel
# Popped element = Teodor
# Popped element = Concepción
# Popped element = Angela
# Popped element = Sō
# Popped element = Amayra
# Popped element = Theodore
# Popped element = Matthías
# Popped element = Hatice
# Popped element = Grace
# Popped element = Gianna
# Popped element = Nagisa
# Popped element = Yulia
# Popped element = Ilgar
# Popped element = Hüseyin
# Popped element = Ana Maria
# Popped element = Odval
# Popped element = Lilien
# Popped element = Bayarmaa
# Popped element = Mei-hui
# Popped element = Filip
# Popped element = Aruuzat
# Popped element = Nikoloz
# Popped element = İnci
# Popped element = Chih-wei
# Popped element = Asilim
# Popped element = Kathem
# Popped element = Ida
# Popped element = Marama
# Popped element = Ofentse
# Popped element = Rayana
# Popped element = Anar
# Popped element = Reza
# Popped element = Mamadou
# Popped element = Ádám
# Popped element = Àlex
# Popped element = Mareva
# Popped element = Max
# Popped element = Esther
# Popped element = Lianne
# Popped element = Fernanda
# Popped element = Sára
# Popped element = Ammar
# Popped element = Mehar
# Popped element = Sebastián
# Popped element = Roel
# Popped element = Vita
# Popped element = Said
# Popped element = Peterson
# Popped element = Kiwa
# Popped element = Dora
# Popped element = Amir-Ali
# Popped element = Isidora
# Popped element = Omphile
# Popped element = Emine
# Popped element = Oliver
# Popped element = Pau
# Popped element = Shu-fen
# Popped element = Awa
# Popped element = Lubanzi
# Popped element = Daris
# Popped element = Andrea
# Popped element = Vasileios
# Popped element = Suzana
# Popped element = Shristi
# Popped element = Lewis
# Popped element = Sonia
# Popped element = Tomás
# Popped element = Teura
# Popped element = Maksim
# Popped element = Anzu
# Popped element = Kārlis
# Popped element = Archie
# Popped element = Nik
# Popped element = Eithan
# Popped element = Astrid
# Popped element = Sobia
# Popped element = Sofi
# Popped element = Maja
# Popped element = Hosna
# Popped element = Azora Kiara
# Popped element = Celine
# Popped element = Emilía
# Popped element = Aisyah
# Popped element = Dániel
# Popped element = Thiago
# Popped element = Ji-an
# Popped element = Benjamin
# Popped element = Ivana
# Popped element = Igor
# Popped element = Sarah
# Popped element = Zeynab
# Popped element = Yusif
# Popped element = Dmitry
# Popped element = Ahmad
# Popped element = Yīnuò
# Popped element = Bisera
# Popped element = Brahim
# Popped element = Shahid
# Popped element = Chloé
# Popped element = Moea
# Popped element = Lucija
# Popped element = Frieda
# Popped element = Nina
# Popped element = Abdulaziz
# Popped element = Areg
# Popped element = Sofiya
# Popped element = Ha-eun
# Popped element = Ha-joon
# Popped element = Gerónimo
# Popped element = Niviaq
# Popped element = Alexandru
# Popped element = Kári
# Popped element = Wan
# Popped element = Eeli
# Popped element = Pablo
# Popped element = Neža
# Popped element = Asel
# Popped element = Ayalah
# Popped element = Jiya
# Popped element = Murad
# Popped element = Daniil
# Popped element = Shu-hua
# Popped element = Eun-woo
# Popped element = Victor Hugo
# Popped element = Charlotte
# Popped element = Baаtar
# Popped element = Elyas
# Popped element = Aviana
# Popped element = Yusuf
# Popped element = Elizabeth
# Popped element = Wassim
# Popped element = Maui
# Popped element = Viraj
# Popped element = Carla
# Popped element = Alejandro
# Popped element = Gagik
# Popped element = Malek
# Popped element = Uiloq
# Popped element = Chloe
# Popped element = Lukas
# Popped element = Abdoulaye
# Popped element = María José
# Popped element = Jógvan
# Popped element = Yǔzé
# Popped element = Jad
# Popped element = Roan
# Popped element = Lavi
# Popped element = Samir
# Popped element = Elif
# Popped element = Franciszek
# Popped element = Lazar
# Popped element = Chuluun
# Popped element = Chih-hao
# Popped element = Batkhaаn
# Popped element = Davi
# Popped element = Aþena
# Popped element = Mary
# Popped element = Xīnyí
# Popped element = Nathalie
# Popped element = Abdullo
# Popped element = Zeinab
# Popped element = Habiba
# Popped element = Lovely
# Popped element = Amir-Abbas
# Popped element = Miguel
# Popped element = Melina
# Popped element = Shivansh
# Popped element = Aarav
# Popped element = Angelo
# Popped element = Ömer Asaf
# Popped element = Eliška
# Popped element = Ian
# Popped element = Chedeline
# Popped element = Albert
# Popped element = Refael
# Popped element = Bintou
# Popped element = Artiom
# Popped element = Marcia
# Popped element = Adin
# Popped element = Abdulla
# Popped element = Kamal
# Popped element = Zina
# Popped element = Martina
# Popped element = Sandra
# Popped element = Carmen
# Popped element = Jacob
# Popped element = Leah
# Popped element = Giulia
# Popped element = Leano
# Popped element = María Fernanda
# Popped element = Rosmery
# Popped element = Snezana
# Popped element = Prakash
# Popped element = Nada
# Popped element = Hudson
# Popped element = Somboon
# Popped element = Sekou
# Popped element = Relja
# Popped element = Davit
# Popped element = Aiur
# Popped element = Adriana
# Popped element = Qillaq
# Popped element = Konstantina
# Popped element = Aleksandr
# Popped element = Alfie
# Popped element = Alice
# Popped element = Elijah
# Popped element = Halim
# Popped element = Maia
# Popped element = Yìchén
# Popped element = Judeline
# Popped element = Elza
# Popped element = Nils
# Popped element = Raya
# Popped element = Amálie
# Popped element = Princess
# Popped element = Bogdana
# Popped element = Ambre
# Popped element = Ria
# Popped element = Valentin
# Popped element = Aliya
# Popped element = Manish
# Popped element = Martim
# Popped element = Daniela
# Popped element = Mohamed
# Popped element = Bader
# Popped element = Tommaso
# Popped element = Somsak
# Popped element = Aputsiaq
# Popped element = Klea
# Popped element = Riko
# Popped element = Abdallah
# Popped element = Sahar
# Popped element = Oisín
# Popped element = Thomas
# Popped element = Laura
# Popped element = Richard
# Popped element = Martha
# Popped element = Victor
# Popped element = Poema
# Popped element = Diego Alejandro
# Popped element = Vugar
# Popped element = Matej
# Popped element = Eisha
# Popped element = Lucía
# Popped element = Tom
# Popped element = Mía
# Popped element = Ayoub
# Popped element = Aleksandra
# Popped element = Angelina
# Popped element = Matilde
# Popped element = Kiara
# Popped element = than
# Popped element = Selma
# Popped element = Lily
# Popped element = Malak
# Popped element = Christian
# Popped element = Noûr
# Popped element = Polina
# Popped element = Varvara
# Popped element = Amira
# Popped element = Kairo
# Popped element = Carl
# Popped element = Hasnaa
# Popped element = Zion
# Popped element = Heitor
# Popped element = İsmail
# Popped element = Aasha
# Popped element = Googoosh
# Popped element = Freja
# Popped element = Hossein
# Popped element = Dan
# Popped element = Somayyeh
# Popped element = Katerina
# Popped element = Petar
# Popped element = Henry
# Popped element = Tomyris
# Popped element = Luciana
# Popped element = Uta
# Popped element = Sofie
# Popped element = Junior
# Popped element = Kirollos
# Popped element = Noemí
# Popped element = Mei-ling
# Popped element = Zofia
# Popped element = Hosniya
# Popped element = Kabita
# Popped element = Hina
# Popped element = Samantha
# Popped element = Lara
# Popped element = Vicente
# Popped element = Tara
# Popped element = Joe
# Popped element = Dorothy
# Popped element = Ruòxī
# Popped element = Abbas
# Popped element = Benjamín
# Popped element = Yousouf
# Popped element = Somchai
# Popped element = Roman
# Popped element = Milagrosa
# Popped element = Daria
# Popped element = Harraz
# Popped element = Naya
# Popped element = Miloš
# Popped element = Yǔxī
# Popped element = Jennifer
# Popped element = Rashad
# Popped element = Fozia
# Popped element = Gaspar
# Popped element = Narine
# Popped element = Huseyn
# Popped element = Ema
# Popped element = Aminata
# Popped element = Narek
# Popped element = Goran
# Popped element = Ciro
# Popped element = Chun-chieh
# Popped element = Edoardo
# Popped element = Isla
# Popped element = María Teresa
# Popped element = Leonardo
# Popped element = Evelina
# Popped element = Emely
# Popped element = Valter
# Popped element = Jerónimo
# Popped element = Gordana
# Popped element = Míngzé
# Popped element = Paulo
# Popped element = Evgeny
# Popped element = Lillie
# Popped element = Marta
# Popped element = Dalal
# Popped element = Jákup
# Popped element = Mio
# Popped element = Bogdan
# Popped element = Noa
# Popped element = Ravi
# Popped element = Tim
# Popped element = Elias
# Popped element = Andriy
# Popped element = Alteo
# Popped element = Dominykas
# Popped element = Leo
# Popped element = Khaled
# Popped element = Fatima
# Popped element = Malthe
# Popped element = Arjun
# Popped element = Sherifa
# Popped element = Amine
# Popped element = Rían
# Popped element = Nia
# Popped element = Hasmik
# Popped element = Yousef
# Popped element = Lucia
# Popped element = Elie
# Popped element = Nomaan
# Popped element = Mona
# Popped element = Emiliya
# Popped element = Ksenija
# Popped element = Finlay
# Popped element = Maxim
# Popped element = Mihail
# Popped element = Dragan
# Popped element = Berrdo
# Popped element = Zehra
# Popped element = Yūma
# Popped element = Ha-yoon
# Popped element = Kazi
# Popped element = Isaac
# Popped element = Aisultan
# Popped element = Djeneba
# Popped element = Aditi
# Popped element = Kyra
# Popped element = Simona
# Popped element = Hussein
# Popped element = Aron
# Popped element = Jónas
# Popped element = Malik
# Popped element = Sophie
# Popped element = Mädïna
# Popped element = Álvaro
# Popped element = Hinata
# Popped element = Shu-hui
# Popped element = Lesedi
# Popped element = Onni
# Popped element = Marie
# Popped element = Ioane
# Popped element = Hawa
# Popped element = Amy
# Popped element = Ayzere
# Popped element = Kiran
# Popped element = Lyna
# Popped element = Ashraqat
# Popped element = Nil
# Popped element = Josip
# Popped element = Nela
# Popped element = Louis
# Popped element = Matthew
# Popped element = Fatoumata
# Popped element = Wen-Hsiung
# Popped element = Tehei
# Popped element = Shayma
# Popped element = Omar
# Popped element = Levi
# Popped element = Kadiatou
# Popped element = Žan
# Popped element = Niel
# Popped element = Lyn
# Popped element = Teo
# Popped element = Martí
# Popped element = Luca
# Popped element = Maha
# Popped element = Asemahle
# Popped element = Robin
# Popped element = Haruma
# Popped element = Natalia
# Popped element = Aitana
# Popped element = Oscar
# Popped element = Marina
# Popped element = Vittoria
# Popped element = Raquel
# Popped element = Veronika
# Popped element = Ali
# Popped element = Lethabo
# Popped element = Himari
# Popped element = Matías
# Popped element = Rosie
# Popped element = Patrícia
# Popped element = Jēkabs
# Popped element = Ethan
# Popped element = Danijel
# Popped element = Evens
# Popped element = John
# Popped element = Umar
# Popped element = Ava
# Popped element = Prem
# Popped element = Nivi
# Popped element = Alessia
# Popped element = Benas
# Popped element = Liepa
# Popped element = Milana
# Popped element = Ariana
# Popped element = Rita
# Popped element = Zǐhán
# Popped element = Nazanin-Zahra
# Popped element = Dimitrios
# Popped element = Aygun
# Popped element = Alisa
# Popped element = Felipe
# Popped element = Nelio
# Popped element = Stella
# Popped element = Maryam
# Popped element = Hayk
# Popped element = Tamatoa
# Popped element = Ellie
# Popped element = Krishna
# Popped element = Samuel
# Popped element = Clara
# Popped element = Patricija
# Popped element = Leandra
# Popped element = Martín
# Popped element = Yoana
# Popped element = Mattias
# Popped element = Muhammed
# Popped element = Athanasios
# Popped element = Eymen
# Popped element = Ginevra
# Popped element = Yusef
# Popped element = Patricia
# Popped element = Liam
# Popped element = Zala
# Popped element = Ramona
# Popped element = Ha-rin
# Popped element = Jordi
# Popped element = Younès
# Popped element = Édouard
# Popped element = Viktorie
# Popped element = Izaro
# Popped element = Elizaveta
# Popped element = Yasna
# Popped element = Alikhan
# Popped element = Mirlande
# Popped element = Yehuda
# Popped element = Yasmine
# Popped element = Penelope
# Popped element = Yǔxuān
# Popped element = Hiro
# Popped element = Eino
# Popped element = Zoe
# Popped element = Mirjana
# Popped element = Oisin
# Popped element = Mariami
# Popped element = Biljana
# Popped element = Aruuke
# Popped element = Agustín
# Popped element = Sevinj
# Popped element = Ona
# Popped element = Kaloyan
# Popped element = Vusala
# Popped element = Leni
# Popped element = Emir
# Popped element = Elija
# Popped element = Ma'soumeh
# Popped element = Theodor
# Popped element = Mabel
# Popped element = Ibai
# Popped element = Tomáš
# Popped element = Bismah
# Popped element = Mahmoud
# Popped element = Tuleen
# Popped element = Duarte
# Popped element = Ayşe
# Popped element = Ronja
# Popped element = Maël
# Popped element = Aariz
# Popped element = Lulwa
# Popped element = Muhammad
# Popped element = Finn
# Popped element = Lian
# Popped element = Elchin
# Popped element = Titaina
# Popped element = Hadicha
# Popped element = Teiva
# Popped element = Pari
# Popped element = Danel
# Popped element = Ahmet
# Popped element = Bibek
# Popped element = Natália
# Popped element = Frederick
# Popped element = Amaia
# Popped element = Ioanna
# Popped element = Ayala
# Popped element = Andrej
# Popped element = Jameson
# Popped element = Itsuki
# Popped element = August
# Popped element = Emiliano
# Popped element = Elmar
# Popped element = Leordo
# Popped element = Marcell
# Popped element = Teva
# Popped element = Dmytro
# Popped element = Guadalupe
# Popped element = Szymon
# Popped element = Ivan
# Popped element = Leen
# Popped element = Amelia
# Popped element = Aleksander
# Popped element = Eylül
# Popped element = Vasilisa
# Popped element = Charles
# Popped element = Danna
# Popped element = Artur
# Popped element = Safija
# Popped element = Salomé
# Popped element = Sem
# Popped element = Lorenzo
# Popped element = Lukáš
# Popped element = Paneeraq
# Popped element = Léo
# Popped element = Alessandro
# Popped element = Damian
# Popped element = Oleksandr
# Popped element = Abdullah
# Popped element = Nurul
# Popped element = Adrian
# Popped element = Ahmed
# Popped element = Emilia
# Popped element = Abdul
# Popped element = María del Carmen
# Popped element = Renata
# Popped element = Aysel
# Popped element = Prasert
# Popped element = César
# Popped element = Myrlande
# Popped element = Kajus
# Popped element = Reem
# Popped element = Tess
# Popped element = Lusine
# Popped element = Lovro
# Popped element = Oliwia
# Popped element = Vera
# Popped element = Matilda
# Popped element = Minik
# Popped element = Aaron
# Popped element = Salma
# Popped element = Antônia
# Popped element = Ji-ho
# Popped element = Abubakr
# Popped element = Mikhail
# Popped element = Mei
# Popped element = Kabir
# Popped element = Ibrahim
# Popped element = Maeva
# Popped element = Liz
# Popped element = Gevorg
# Popped element = Farrah
# Popped element = Elena
# Popped element = Elnur
# Popped element = Ariel
# Popped element = Meriem
# Popped element = Mohammed
# Popped element = Emil
# Popped element = Panagiota
# Popped element = Mariya
# Popped element = Markas
# Popped element = Danylo
# Popped element = Salik
# Popped element = Mohammad-Reza
# Popped element = Tapuarii
# Popped element = Ellen
# Popped element = Barbare
# Popped element = Mohammad-Taha
# Popped element = Mehmet
# Popped element = Marko
# Popped element = Pola
# Popped element = Eitan
# Popped element = Dimitra
# Popped element = Lía
# Popped element = Elshan
# Popped element = Zuzanna
# Popped element = Gael
# Popped element = Julie
# Popped element = Lilly
# Popped element = Monte
# Popped element = Mikaere
# Popped element = Yǐmò
# Popped element = Inunnguag
# Popped element = Bolormaa
# Popped element = Venla
# Popped element = Latifa
# Popped element = Haruna
# Popped element = Helmi
# Popped element = Fahd
# Popped element = Shahd
# Popped element = Hinato
# Popped element = Dion
# Popped element = Ji-a
# Popped element = Abdelkader
# Popped element = Anastasia

# %% [markdown]
# __Ok, that was interesting, but when do we want to use a while loop?__
#
# * A while loop is useful when the number of iterations is not known in advance and depends on dynamic conditions during execution. It allows for more flexible control over the loop's termination based on changing conditions, making it suitable for scenarios where the loop's exit criteria are not predetermined.
# * While loops are often used for tasks like reading data until the end of a file, waiting for a specific condition to be met, or processing items in a collection until all items are processed. They are also useful for implementing algorithms that require repeated execution until a certain condition is satisfied, such as searching, sorting, or iterating through data structures.
#
# There were also a few other things in our while loop implementation, such as the [if else statement](https://docs.julialang.org/en/v1/base/control-flow/#if-elseif-else).  This is an example of [conditional evaluation](https://docs.julialang.org/en/v1/manual/control-flow/#man-conditional-evaluation) that allows us to execute different blocks of code based on whether a condition is true or false.
#
# ___
